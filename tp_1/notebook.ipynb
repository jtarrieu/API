# %% [markdown]
# > JEREMY TARRIEU  DEA2 (désolé du retard)

# %% [markdown]
# # General Knowledge of API
#
# APIs, or Application Programming Interfaces, play a pivotal role in modern software development by facilitating communication and data exchange between different systems. They serve as bridges that allow applications to interact with each other seamlessly, enabling the creation of more robust and interconnected software.
#
# APIs come in various forms, each serving specific purposes in the realm of software development. Let's explore some fundamental concepts:

# %% [markdown]
# - **Question 1:** *Name three types of API protocols. Briefly explain the primary use of each.*
#
#   - REST: stateless communication, independant interactions, GET POST PUT DELETE
#
#   - SOAP: set of rules for structuring messages, using XML, HTTPS, SMTP
#
#   - GraphQL: allow clientq to request only the data they need
#
#
#
#
# - **Question 2:** *What are the HTTP response code families? And what do they mean?*
#
#   - 1XX - INFO
#   - 2XX - SUCCESS
#   - 3XX - REDIRECT
#   - 4XX - CLIENT ERROR
#   - 5XX - SERVER ERROR
#
#   Understanding these families helps developers diagnose and troubleshoot issues during API interactions.
#
# - **Question 3:** *What do the HTTP response codes 201, 401, and 404 mean?*
#
#   - **201:** Created
#   - **401:** Unauthorized
#   - **404:** Page not found
#
# - **Question 4:** *Name the 4 basic HTTP verbs.*
#
#   - GET
#   - POST
#   - DELETE
#   - PUT
#
# - **Question 5:** *Explain the difference between PUT and PATCH?*
#
#   - **PUT:** : Modify a ressource entirely
#
#   - **PATCH:** : Modify a ressource partially
#
# - **Question 6:** *Name at least two data formats commonly used in API exchanges.*
#
#   - JSON
#
#   - XML
#
# - **Question 7:** *How can you verify the validity of a resource without getting the entire response?*
#
#   - Ask for a list of ressources
#
# - **Question 8:** *What are the main concepts of REST? (name them)*
#
#   - Layered System
#   - Client-server
#   - Stateless
#   - Cacheable
#
# - **Question 9:** *Can you explain one of the main concepts of your choice from among those you mention? (Give an example if possible)*
#
#   - The layering allow for instance to query specific data in specific categories. Like GET http://website.com/api/bikes/two_wheels/brands and also http://website.com/api/bikes/two_wheels
#
# In the subsequent sections, we will delve into practical exercises to apply and deepen our understanding of these concepts using SOAP, REST, and GraphQL APIs.

# %% [markdown]
# --------------------------

# %% [markdown]
# # Exploring SOAP APIs
#
# ### Few elements to remember about the SOAP Protocol
#
# The SOAP protocol, which means Simple Object Access Protocol, is one of the earliest web service protocols. SOAP is an XML-based protocol and was designed to provide a platform/language-independent way to exchange data between different systems over the internet.
#
# ### Key Concepts in SOAP:
#
# - **XML-Based Structure:** SOAP messages are structured using XML, making them both human-readable and machine-readable. This structure allows for the encapsulation of data and its transport between systems.
#
# - **Platform and Language Independence:** One of the core objectives of SOAP is to provide a communication method that is independent of the underlying platform or programming language. This promotes interoperability between diverse systems.
#
# - **Message Format:** SOAP messages consist of an envelope that defines the message structure and rules for processing, a set of encoding rules for data types, and conventions for representing remote procedure calls.
#
# - **Transport Neutrality:** SOAP can be used with various transport protocols, including HTTP, SMTP, and more. This flexibility in transport makes it adaptable to different network environments.
#
# ### Objective
#
# Obtain and display the capital of the Canada corresponding to the ISO code "CA" using the following SOAP API.
# Step by step guide :
#
# - **Step 1:** Examine the XML structure of the SOAP request provided. Identify the tag name that contains the ISO country code and the tag that will return the capital name.
#
# - **Step 2:** Modify the existing SOAP request to use the ISO code "CA" isntead of "FR". Ensure that the XML structure remains correct.
#
# - **Step 3:** Use the modified request to send a request to the SOAP services at the specified URL.
#
# - **Step 4:** Analyze the response received. Extract and display the capital name from the SOAP response.
#
# - **Step 5:** Remove sections of code that are not necessary to achieve this objective, in order to simply the script.
#
#
# ### Documentation link :
#
# - https://www.postman.com/cs-demo/workspace/postman-customer-org-s-public-workspace/documentation/8854915-43f6a9be-0c65-4486-bfdf-36b6548161dd?entity=request-96a53688-6305-45be-ab8b-ca1d1c88f830
# - https://docs.insomnia.rest/

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/jeremytarrieu/miniconda3/envs/api/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jeremytarrieu/miniconda3/envs/api/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jeremytarrieu/miniconda3/envs/api/lib/python3.12/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jeremytarrieu/miniconda3/envs/api/lib/python3.12/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jeremytarrieu/miniconda3/envs/api/lib/python3.12/site-packages (from requests) (2023.11.17)

# %%
import requests

# %%
# SOAP request URL
url = "http://webservices.oorsprong.org/websamples.countryinfo/CountryInfoService.wso"

# structured XML
payload = """<soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/">
                <soap:Body>
                    <CapitalCity xmlns="http://www.oorsprong.org/websamples.countryinfo">
                        <sCountryISOCode>FR</sCountryISOCode>
                    </CapitalCity>
                </soap:Body>
                </soap:Envelope>"""
# headers
headers = {
    'Content-Type': 'text/xml; charset=utf-8'
}
# POST request
response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/">
#   <soap:Body>
#     <m:CapitalCityResponse xmlns:m="http://www.oorsprong.org/websamples.countryinfo">
#       <m:CapitalCityResult>Paris</m:CapitalCityResult>
#     </m:CapitalCityResponse>
#   </soap:Body>
# </soap:Envelope>

# %%
def extract_capital_name(text_response:str)->str:
    """Extract the capital name from the XML response.

    Args:
        text_response (str): XML response.text

    Returns:
        str: capital city name
    """
    return text_response.split('<m:CapitalCityResult>')[1].split('</m:CapitalCityResult>')[0]

# %%
extract_capital_name(response.text)
# Out:
# 'Paris'

# %% [markdown]
# --------------------------

# %% [markdown]
# # REST API Exercise: Star Wars Information Retrieval
#
# ### Introduction
#
# In the exercice, you will explore the Star Wars API (SWAPI) to retrieve and analyze data related to Star Wars characters, films and planets. The SWAPI API is a RESTful web service that provideinformation about Star Wars universe, accessible through various endpoints.\
# This exercice is designed to enhance your understanding of working with RESTful APIs, feel free to ask me if you have any question. Each task will build on the previous one so don't hesitate if you are blocked. Make sure to handle bad response code.
#
# ### Few elements to remember about the REST Protocol
#
# REST (Representational State Transfer) is an architectural style for designing networked applications. RESTful APIs (Application Programming Interfaces) conform to the principles of REST, allowing systems to communicate over HTTP in a stateless manner; Some important aspects are:
#
# - **Resources:** Everything is a resource, identified by a unique URI.
#
# - **HTTP Methods:** CRUD operations are performed using standard HTTP methods (GET, POST, PUT, DELETE).
#
# - **Stateless:** Each request from a client contains all the information needed to understand and fulfill the request.
#
# ### Key Concepts in REST:
#
# - **Endpoint:** A specific URI representing a resource. Endpoints are URLs that define where resources can be accessed.
#
# - **Basic HTTP Methods:** One of the core objectives of SOAP is to provide a communication method that is independent of the underlying platform or programming language. This promotes interoperability between diverse systems.
#     - **GET:** Retrieve data from a specified resource.
#     - **POST:** Submit data to be processed to a specified resource.
#     - **PUT:** Update a resource.
#     - **DELETE:** Delete a resource.
#
# - **Request and Response:**
#     - **Request:** The client's message to the server, including the HTTP method, headers, and optional data.
#     - **Response:** The server's reply to the client's request, containing status information and, optionally, data.
#
#
# ### Objective
#
# - **Step 1: Introduction:** Find some informations about the SWAPI API : the base URL, the Rate limiting and How to auhtenticate. Find information on all available resources withing this API with a request.

# %% [markdown]
# **Rate limiting**\
# Swapi has rate limiting to prevent malicious abuse (as if anyone would abuse Star Wars data!) and to make sure our service can handle a potentially large amount of traffic. Rate limiting is done via IP address and is currently limited to 10,000 API request per day. This is enough to request all the data on the website at least ten times over. There should be no reason for hitting the rate limit.
#
# **Authentication**\
# Swapi is a completely open API. No authentication is required to query and get data. This also means that we've limited what you can do to just GET-ing the data. If you find a mistake in the data, then tweet the author or email him.

# %%
import requests

# %%
def send_request(url:str, params:dict={})->dict:
    return requests.get(url, params=params).json()

# %%
base_url = 'https://swapi.dev/api/'
routes = send_request(base_url)
routes
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %% [markdown]
# - **Step 2: Retrieve Character Information:** Retrieve all characters informations (name, gender, height, ...).

# %%
people = send_request(routes['people'])
people;

# %% [markdown]
# - **Step 3: Retrieve Film Information:** Retrieve all films informations (title, director, release date, ...).

# %%
films = send_request(routes['films'])
films;

# %% [markdown]
# - **Step 4: Retrieve Planet Information:** Retrieve all planets informations (name, population, climate, ...).

# %%
planets = send_request(routes['planets'])
planets;

# %% [markdown]
# - **Step 5: Search and Display:** Create a function to search for and display information about a specific character based on its name. Be sure to handle cases of bad queries and to make at least three unittests with an understandable name.

# %%
def search_name(name:str)->dict:
    response = requests.get('https://swapi.dev/api/people/', params={'search': name}).json()

    if response == {'count': 0, 'next': None, 'previous': None, 'results': []}:
        return 'no match'
    return response

# %%
import unittest

class SearchNameTest(unittest.TestCase):
    def test_search_name_correct_match_value(self):
        response = 1
        self.assertEqual(search_name('Luke')['count'], response)
    
    def test_search_name_correct_match_type(self):
        response_type = dict
        self.assertEqual(type(search_name('Luke')), response_type)

    def test_search_name_no_match(self):
        response = 'no match'
        self.assertEqual(search_name('not a name'), response)
    
    def test_search_name_no_match_type(self):
        response = str
        self.assertEqual(type(search_name('not a name')), response)


unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_search_name_correct_match_type (__main__.SearchNameTest.test_search_name_correct_match_type) ... ok
# test_search_name_correct_match_value (__main__.SearchNameTest.test_search_name_correct_match_value) ... ok
# test_search_name_no_match (__main__.SearchNameTest.test_search_name_no_match) ... ok
# test_search_name_no_match_type (__main__.SearchNameTest.test_search_name_no_match_type) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 3.576s
#
# OK

# %% [markdown]
# - **Step 6: Advanced Query:** Store in a pandas dataframe all informations about all the characters of the film you want. Group the characters by species at the end.

# %%
import pandas as pd

# %%
def search_characters_of_a_film(film:str)->pd.DataFrame:
    response = requests.get('https://swapi.dev/api/films/', params={'search': film})
    characters_url_list = response.json()['results'][0]['characters']
    character_info_list = [send_request(url) for url in characters_url_list ]
    character_df = pd.DataFrame(character_info_list)
    return character_df

df = search_characters_of_a_film('A New Hope')
df
# Out:
#                      name height     mass     hair_color        skin_color  \
# 0          Luke Skywalker    172       77          blond              fair
# 1                   C-3PO    167       75            n/a              gold
# 2                   R2-D2     96       32            n/a       white, blue
# 3             Darth Vader    202      136           none             white
# 4             Leia Organa    150       49          brown             light
# 5               Owen Lars    178      120    brown, grey             light
# 6      Beru Whitesun lars    165       75          brown             light
# 7                   R5-D4     97       32            n/a        white, red
# 8       Biggs Darklighter    183       84          black             light
# 9          Obi-Wan Kenobi    182       77  auburn, white              fair
# 10         Wilhuff Tarkin    180  unknown   auburn, grey              fair
# 11              Chewbacca    228      112          brown           unknown
# 12               Han Solo    180       80          brown              fair
# 13                 Greedo    173       74            n/a             green
# 14  Jabba Desilijic Tiure    175    1,358            n/a  green-tan, brown
# 15         Wedge Antilles    170       77          brown              fair
# 16       Jek Tono Porkins    180      110          brown              fair
# 17        Raymus Antilles    188       79          brown             light
#
#     eye_color birth_year         gender                          homeworld  \
# 0        blue      19BBY           male   https://swapi.dev/api/planets/1/
# 1      yellow     112BBY            n/a   https://swapi.dev/api/planets/1/
# 2         red      33BBY            n/a   https://swapi.dev/api/planets/8/
# 3      yellow    41.9BBY           male   https://swapi.dev/api/planets/1/
# 4       brown      19BBY         female   https://swapi.dev/api/planets/2/
# 5        blue      52BBY           male   https://swapi.dev/api/planets/1/
# 6        blue      47BBY         female   https://swapi.dev/api/planets/1/
# 7         red    unknown            n/a   https://swapi.dev/api/planets/1/
# 8       brown      24BBY           male   https://swapi.dev/api/planets/1/
# 9   blue-gray      57BBY           male  https://swapi.dev/api/planets/20/
# 10       blue      64BBY           male  https://swapi.dev/api/planets/21/
# 11       blue     200BBY           male  https://swapi.dev/api/planets/14/
# 12      brown      29BBY           male  https://swapi.dev/api/planets/22/
# 13      black      44BBY           male  https://swapi.dev/api/planets/23/
# 14     orange     600BBY  hermaphrodite  https://swapi.dev/api/planets/24/
# 15      hazel      21BBY           male  https://swapi.dev/api/planets/22/
# 16       blue    unknown           male  https://swapi.dev/api/planets/26/
# 17      brown    unknown           male   https://swapi.dev/api/planets/2/
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3   [https://swapi.dev/api/films/1/, https://swapi...
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# 5   [https://swapi.dev/api/films/1/, https://swapi...
# 6   [https://swapi.dev/api/films/1/, https://swapi...
# 7                    [https://swapi.dev/api/films/1/]
# 8                    [https://swapi.dev/api/films/1/]
# 9   [https://swapi.dev/api/films/1/, https://swapi...
# 10  [https://swapi.dev/api/films/1/, https://swapi...
# 11  [https://swapi.dev/api/films/1/, https://swapi...
# 12  [https://swapi.dev/api/films/1/, https://swapi...
# 13                   [https://swapi.dev/api/films/1/]
# 14  [https://swapi.dev/api/films/1/, https://swapi...
# 15  [https://swapi.dev/api/films/1/, https://swapi...
# 16                   [https://swapi.dev/api/films/1/]
# 17  [https://swapi.dev/api/films/1/, https://swapi...
#
#                                species  \
# 0                                   []
# 1   [https://swapi.dev/api/species/2/]
# 2   [https://swapi.dev/api/species/2/]
# 3                                   []
# 4                                   []
# 5                                   []
# 6                                   []
# 7   [https://swapi.dev/api/species/2/]
# 8                                   []
# 9                                   []
# 10                                  []
# 11  [https://swapi.dev/api/species/3/]
# 12                                  []
# 13  [https://swapi.dev/api/species/4/]
# 14  [https://swapi.dev/api/species/5/]
# 15                                  []
# 16                                  []
# 17                                  []
#
#                                              vehicles  \
# 0   [https://swapi.dev/api/vehicles/14/, https://s...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                [https://swapi.dev/api/vehicles/30/]
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                [https://swapi.dev/api/vehicles/38/]
# 10                                                 []
# 11               [https://swapi.dev/api/vehicles/19/]
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15               [https://swapi.dev/api/vehicles/14/]
# 16                                                 []
# 17                                                 []
#
#                                             starships  \
# 0   [https://swapi.dev/api/starships/12/, https://...
# 1                                                  []
# 2                                                  []
# 3               [https://swapi.dev/api/starships/13/]
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8               [https://swapi.dev/api/starships/12/]
# 9   [https://swapi.dev/api/starships/48/, https://...
# 10                                                 []
# 11  [https://swapi.dev/api/starships/10/, https://...
# 12  [https://swapi.dev/api/starships/10/, https://...
# 13                                                 []
# 14                                                 []
# 15              [https://swapi.dev/api/starships/12/]
# 16              [https://swapi.dev/api/starships/12/]
# 17                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5   2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6   2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 7   2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
# 8   2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9   2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
# 10  2014-12-10T16:26:56.138000Z  2014-12-20T21:17:50.330000Z
# 11  2014-12-10T16:42:45.066000Z  2014-12-20T21:17:50.332000Z
# 12  2014-12-10T16:49:14.582000Z  2014-12-20T21:17:50.334000Z
# 13  2014-12-10T17:03:30.334000Z  2014-12-20T21:17:50.336000Z
# 14  2014-12-10T17:11:31.638000Z  2014-12-20T21:17:50.338000Z
# 15  2014-12-12T11:08:06.469000Z  2014-12-20T21:17:50.341000Z
# 16  2014-12-12T11:16:56.569000Z  2014-12-20T21:17:50.343000Z
# 17  2014-12-20T19:49:35.583000Z  2014-12-20T21:17:50.493000Z
#
#                                  url
# 0    https://swapi.dev/api/people/1/
# 1    https://swapi.dev/api/people/2/
# 2    https://swapi.dev/api/people/3/
# 3    https://swapi.dev/api/people/4/
# 4    https://swapi.dev/api/people/5/
# 5    https://swapi.dev/api/people/6/
# 6    https://swapi.dev/api/people/7/
# 7    https://swapi.dev/api/people/8/
# 8    https://swapi.dev/api/people/9/
# 9   https://swapi.dev/api/people/10/
# 10  https://swapi.dev/api/people/12/
# 11  https://swapi.dev/api/people/13/
# 12  https://swapi.dev/api/people/14/
# 13  https://swapi.dev/api/people/15/
# 14  https://swapi.dev/api/people/16/
# 15  https://swapi.dev/api/people/18/
# 16  https://swapi.dev/api/people/19/
# 17  https://swapi.dev/api/people/81/

# %%
def groupby_species(character_df:pd.DataFrame)->pd.DataFrame:
    # Replace "[]" with NaN in the 'species' column
    df = character_df.copy()
    df['species'] = df['species'].apply(lambda x: x[0] if x else None)
    df.fillna('NA', inplace=True)

    exploded_df = df.explode('species')
    # Grouping by 'species' and creating a new DataFrame
    grouped_df = exploded_df.groupby('species').apply(lambda x: x)
    return grouped_df

groupby_species(df)
# Out:
#                                                       name height     mass  \
# species
# NA                               0          Luke Skywalker    172       77
#                                  3             Darth Vader    202      136
#                                  4             Leia Organa    150       49
#                                  5               Owen Lars    178      120
#                                  6      Beru Whitesun lars    165       75
#                                  8       Biggs Darklighter    183       84
#                                  9          Obi-Wan Kenobi    182       77
#                                  10         Wilhuff Tarkin    180  unknown
#                                  12               Han Solo    180       80
#                                  15         Wedge Antilles    170       77
#                                  16       Jek Tono Porkins    180      110
#                                  17        Raymus Antilles    188       79
# https://swapi.dev/api/species/2/ 1                   C-3PO    167       75
#                                  2                   R2-D2     96       32
#                                  7                   R5-D4     97       32
# https://swapi.dev/api/species/3/ 11              Chewbacca    228      112
# https://swapi.dev/api/species/4/ 13                 Greedo    173       74
# https://swapi.dev/api/species/5/ 14  Jabba Desilijic Tiure    175    1,358
#
#                                         hair_color        skin_color  \
# species
# NA                               0           blond              fair
#                                  3            none             white
#                                  4           brown             light
#                                  5     brown, grey             light
#                                  6           brown             light
#                                  8           black             light
#                                  9   auburn, white              fair
#                                  10   auburn, grey              fair
#                                  12          brown              fair
#                                  15          brown              fair
#                                  16          brown              fair
#                                  17          brown             light
# https://swapi.dev/api/species/2/ 1             n/a              gold
#                                  2             n/a       white, blue
#                                  7             n/a        white, red
# https://swapi.dev/api/species/3/ 11          brown           unknown
# https://swapi.dev/api/species/4/ 13            n/a             green
# https://swapi.dev/api/species/5/ 14            n/a  green-tan, brown
#
#                                      eye_color birth_year         gender  \
# species
# NA                               0        blue      19BBY           male
#                                  3      yellow    41.9BBY           male
#                                  4       brown      19BBY         female
#                                  5        blue      52BBY           male
#                                  6        blue      47BBY         female
#                                  8       brown      24BBY           male
#                                  9   blue-gray      57BBY           male
#                                  10       blue      64BBY           male
#                                  12      brown      29BBY           male
#                                  15      hazel      21BBY           male
#                                  16       blue    unknown           male
#                                  17      brown    unknown           male
# https://swapi.dev/api/species/2/ 1      yellow     112BBY            n/a
#                                  2         red      33BBY            n/a
#                                  7         red    unknown            n/a
# https://swapi.dev/api/species/3/ 11       blue     200BBY           male
# https://swapi.dev/api/species/4/ 13      black      44BBY           male
# https://swapi.dev/api/species/5/ 14     orange     600BBY  hermaphrodite
#
#                                                              homeworld  \
# species
# NA                               0    https://swapi.dev/api/planets/1/
#                                  3    https://swapi.dev/api/planets/1/
#                                  4    https://swapi.dev/api/planets/2/
#                                  5    https://swapi.dev/api/planets/1/
#                                  6    https://swapi.dev/api/planets/1/
#                                  8    https://swapi.dev/api/planets/1/
#                                  9   https://swapi.dev/api/planets/20/
#                                  10  https://swapi.dev/api/planets/21/
#                                  12  https://swapi.dev/api/planets/22/
#                                  15  https://swapi.dev/api/planets/22/
#                                  16  https://swapi.dev/api/planets/26/
#                                  17   https://swapi.dev/api/planets/2/
# https://swapi.dev/api/species/2/ 1    https://swapi.dev/api/planets/1/
#                                  2    https://swapi.dev/api/planets/8/
#                                  7    https://swapi.dev/api/planets/1/
# https://swapi.dev/api/species/3/ 11  https://swapi.dev/api/planets/14/
# https://swapi.dev/api/species/4/ 13  https://swapi.dev/api/planets/23/
# https://swapi.dev/api/species/5/ 14  https://swapi.dev/api/planets/24/
#
#                                                                                  films  \
# species
# NA                               0   [https://swapi.dev/api/films/1/, https://swapi...
#                                  3   [https://swapi.dev/api/films/1/, https://swapi...
#                                  4   [https://swapi.dev/api/films/1/, https://swapi...
#                                  5   [https://swapi.dev/api/films/1/, https://swapi...
#                                  6   [https://swapi.dev/api/films/1/, https://swapi...
#                                  8                    [https://swapi.dev/api/films/1/]
#                                  9   [https://swapi.dev/api/films/1/, https://swapi...
#                                  10  [https://swapi.dev/api/films/1/, https://swapi...
#                                  12  [https://swapi.dev/api/films/1/, https://swapi...
#                                  15  [https://swapi.dev/api/films/1/, https://swapi...
#                                  16                   [https://swapi.dev/api/films/1/]
#                                  17  [https://swapi.dev/api/films/1/, https://swapi...
# https://swapi.dev/api/species/2/ 1   [https://swapi.dev/api/films/1/, https://swapi...
#                                  2   [https://swapi.dev/api/films/1/, https://swapi...
#                                  7                    [https://swapi.dev/api/films/1/]
# https://swapi.dev/api/species/3/ 11  [https://swapi.dev/api/films/1/, https://swapi...
# https://swapi.dev/api/species/4/ 13                   [https://swapi.dev/api/films/1/]
# https://swapi.dev/api/species/5/ 14  [https://swapi.dev/api/films/1/, https://swapi...
#
#                                                               species  \
# species
# NA                               0                                 NA
#                                  3                                 NA
#                                  4                                 NA
#                                  5                                 NA
#                                  6                                 NA
#                                  8                                 NA
#                                  9                                 NA
#                                  10                                NA
#                                  12                                NA
#                                  15                                NA
#                                  16                                NA
#                                  17                                NA
# https://swapi.dev/api/species/2/ 1   https://swapi.dev/api/species/2/
#                                  2   https://swapi.dev/api/species/2/
#                                  7   https://swapi.dev/api/species/2/
# https://swapi.dev/api/species/3/ 11  https://swapi.dev/api/species/3/
# https://swapi.dev/api/species/4/ 13  https://swapi.dev/api/species/4/
# https://swapi.dev/api/species/5/ 14  https://swapi.dev/api/species/5/
#
#                                                                               vehicles  \
# species
# NA                               0   [https://swapi.dev/api/vehicles/14/, https://s...
#                                  3                                                  []
#                                  4                [https://swapi.dev/api/vehicles/30/]
#                                  5                                                  []
#                                  6                                                  []
#                                  8                                                  []
#                                  9                [https://swapi.dev/api/vehicles/38/]
#                                  10                                                 []
#                                  12                                                 []
#                                  15               [https://swapi.dev/api/vehicles/14/]
#                                  16                                                 []
#                                  17                                                 []
# https://swapi.dev/api/species/2/ 1                                                  []
#                                  2                                                  []
#                                  7                                                  []
# https://swapi.dev/api/species/3/ 11               [https://swapi.dev/api/vehicles/19/]
# https://swapi.dev/api/species/4/ 13                                                 []
# https://swapi.dev/api/species/5/ 14                                                 []
#
#                                                                              starships  \
# species
# NA                               0   [https://swapi.dev/api/starships/12/, https://...
#                                  3               [https://swapi.dev/api/starships/13/]
#                                  4                                                  []
#                                  5                                                  []
#                                  6                                                  []
#                                  8               [https://swapi.dev/api/starships/12/]
#                                  9   [https://swapi.dev/api/starships/48/, https://...
#                                  10                                                 []
#                                  12  [https://swapi.dev/api/starships/10/, https://...
#                                  15              [https://swapi.dev/api/starships/12/]
#                                  16              [https://swapi.dev/api/starships/12/]
#                                  17                                                 []
# https://swapi.dev/api/species/2/ 1                                                  []
#                                  2                                                  []
#                                  7                                                  []
# https://swapi.dev/api/species/3/ 11  [https://swapi.dev/api/starships/10/, https://...
# https://swapi.dev/api/species/4/ 13                                                 []
# https://swapi.dev/api/species/5/ 14                                                 []
#
#                                                          created  \
# species
# NA                               0   2014-12-09T13:50:51.644000Z
#                                  3   2014-12-10T15:18:20.704000Z
#                                  4   2014-12-10T15:20:09.791000Z
#                                  5   2014-12-10T15:52:14.024000Z
#                                  6   2014-12-10T15:53:41.121000Z
#                                  8   2014-12-10T15:59:50.509000Z
#                                  9   2014-12-10T16:16:29.192000Z
#                                  10  2014-12-10T16:26:56.138000Z
#                                  12  2014-12-10T16:49:14.582000Z
#                                  15  2014-12-12T11:08:06.469000Z
#                                  16  2014-12-12T11:16:56.569000Z
#                                  17  2014-12-20T19:49:35.583000Z
# https://swapi.dev/api/species/2/ 1   2014-12-10T15:10:51.357000Z
#                                  2   2014-12-10T15:11:50.376000Z
#                                  7   2014-12-10T15:57:50.959000Z
# https://swapi.dev/api/species/3/ 11  2014-12-10T16:42:45.066000Z
# https://swapi.dev/api/species/4/ 13  2014-12-10T17:03:30.334000Z
# https://swapi.dev/api/species/5/ 14  2014-12-10T17:11:31.638000Z
#
#                                                           edited  \
# species
# NA                               0   2014-12-20T21:17:56.891000Z
#                                  3   2014-12-20T21:17:50.313000Z
#                                  4   2014-12-20T21:17:50.315000Z
#                                  5   2014-12-20T21:17:50.317000Z
#                                  6   2014-12-20T21:17:50.319000Z
#                                  8   2014-12-20T21:17:50.323000Z
#                                  9   2014-12-20T21:17:50.325000Z
#                                  10  2014-12-20T21:17:50.330000Z
#                                  12  2014-12-20T21:17:50.334000Z
#                                  15  2014-12-20T21:17:50.341000Z
#                                  16  2014-12-20T21:17:50.343000Z
#                                  17  2014-12-20T21:17:50.493000Z
# https://swapi.dev/api/species/2/ 1   2014-12-20T21:17:50.309000Z
#                                  2   2014-12-20T21:17:50.311000Z
#                                  7   2014-12-20T21:17:50.321000Z
# https://swapi.dev/api/species/3/ 11  2014-12-20T21:17:50.332000Z
# https://swapi.dev/api/species/4/ 13  2014-12-20T21:17:50.336000Z
# https://swapi.dev/api/species/5/ 14  2014-12-20T21:17:50.338000Z
#
#                                                                   url
# species
# NA                               0    https://swapi.dev/api/people/1/
#                                  3    https://swapi.dev/api/people/4/
#                                  4    https://swapi.dev/api/people/5/
#                                  5    https://swapi.dev/api/people/6/
#                                  6    https://swapi.dev/api/people/7/
#                                  8    https://swapi.dev/api/people/9/
#                                  9   https://swapi.dev/api/people/10/
#                                  10  https://swapi.dev/api/people/12/
#                                  12  https://swapi.dev/api/people/14/
#                                  15  https://swapi.dev/api/people/18/
#                                  16  https://swapi.dev/api/people/19/
#                                  17  https://swapi.dev/api/people/81/
# https://swapi.dev/api/species/2/ 1    https://swapi.dev/api/people/2/
#                                  2    https://swapi.dev/api/people/3/
#                                  7    https://swapi.dev/api/people/8/
# https://swapi.dev/api/species/3/ 11  https://swapi.dev/api/people/13/
# https://swapi.dev/api/species/4/ 13  https://swapi.dev/api/people/15/
# https://swapi.dev/api/species/5/ 14  https://swapi.dev/api/people/16/

# %% [markdown]
# - **Step 7: Data Analysis:** Create an advanced query to retrieve information on all the films, and find a way to rank them according to the number of characters in the film.

# %%
# Step 1: Retrieve information on all the films
url = "https://swapi.dev/api/films"
params = {}

response = requests.get(url, params=params)
data = response.json()

# Step 2: Extract film titles and character URLs
films = data['results']
film_characters = {}

# Step 3: Retrieve character data for each film
for film in films:
    title = film['title']
    characters = film['characters']
    character_count = len(characters)
    
    # Step 4: Count the number of characters for each film
    film_characters[title] = character_count

# Step 5: Sort films based on the number of characters
ranked_films = sorted(film_characters.items(), key=lambda x: x[1], reverse=True)

# Step 6: Display the ranked films
for film, character_count in ranked_films:
    print(f"Film: {film}, Number of Characters: {character_count}")

# display the dataset sorted by the count of the number of characters
ranked_films
# Out:
# Film: Attack of the Clones, Number of Characters: 40
# Film: The Phantom Menace, Number of Characters: 34
# Film: Revenge of the Sith, Number of Characters: 34
# Film: Return of the Jedi, Number of Characters: 20
# Film: A New Hope, Number of Characters: 18
# Film: The Empire Strikes Back, Number of Characters: 16
# [('Attack of the Clones', 40),
#  ('The Phantom Menace', 34),
#  ('Revenge of the Sith', 34),
#  ('Return of the Jedi', 20),
#  ('A New Hope', 18),
#  ('The Empire Strikes Back', 16)]

# %% [markdown]
# - **Step 8 bonus: Additional Endpoint:** Explore an additional endpoint and make a request to display relevant information. For exemple to retrieve starship or vehicles informations.

# %%
url = "https://swapi.dev/api/starships/"
params = {}

response = requests.get(url, params=params)
data = response.json()
data;

# %% [markdown]
# ### Documentation link :
#
# - https://swapi.dev/documentation

# %% [markdown]
# ### Postman a powerfull tool for

# %% [markdown]
# --------------------------

# %% [markdown]
# # Exploring GraphQL APIs

# %% [markdown]
# Usefull links:
# - https://graphql.org/learn/queries/
# - https://graphql-demo.mead.io/
#
# Use this graphQL API to make complex requests on Star Wars world:
# - https://swapi-graphql.netlify.app/

# %% [markdown]
# On the below cell you have a simple graphQL query.

# %% [markdown]
# # Exploring Star Wars Data with GraphQL
#
# ### Introduction
#
# In this exercice you will retrieve the previous results in another way, by consuming the GraphQL API of SWAPI.
#
# ### Few elements to remember about the GraphQL Protocol
#
# GraphQL is a powerful query language for APIs that provides a more efficient and flexible alternative to traditional REST APIs. In this exercise, we will interact with the Star Wars API (SWAPI) using GraphQL to retrieve specific information about characters, films, and species from the Star Wars universe. Some important aspects are:
#
# - **Single Endpoint:** GraphQL APIs typically have a single endpoint for all queries, making it more straightforward to manage and interact with.
#
# - **Flexible Responses:** Clients receive exactly the data they request, reducing over-fetching of data common in traditional REST APIs.
#
# - **Introspection:** GraphQL supports introspection, allowing clients to query the schema itself, making it self-documenting and aiding in development.
#
# ### Key Concepts in GraphQL:
#
# - **GraphQL Schema:** GraphQL APIs have a schema that defines the types of data available and the relationships between them.
#
# - **Queries:** In GraphQL, clients specify the exact data they need using queries, allowing for more efficient data retrieval.
#
# - **Fields and Nested Structures:** Queries can include specific fields, and GraphQL supports nested structures to retrieve related data in a single request.
#
#
# ### Objective
#
# - **Step 1: Introduction:** Understand the REST API Query. You can use the playground for this : https://swapi-graphql.netlify.app/?query=%7B%0A%20%20allFilms%20%7B%0A%20%20%20%20edges%20%7B%0A%20%20%20%20%20%20node%20%7B%0A%20%20%20%20%20%20%20%20id%2C%0A%20%20%20%20%20%20%20%20title%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%7D%0A%7D
#
# - **Step 2: Retrieve Films with Character Information:** Retrieve Films with Character Information in a single query.
#
#
# ### Documentation link :
#
# - https://swapi.dev/documentation

# %%
url = "https://swapi-graphql.netlify.app/.netlify/functions/index"

# GraphQL query to retrieve film titles
body = """
query {
  allFilms {
    edges {
      node {
        title
        characterConnection {
          characters {
            name
          }
        }
      }
    }
  }
}
"""


response = requests.post(url, json={"query": body})
print("response status code:", response.status_code)

if response.status_code == 200:
    print("response:", response.json())
# Out:
# response status code: 200
# response: {'data': {'allFilms': {'edges': [{'node': {'title': 'A New Hope', 'characterConnection': {'characters': [{'name': 'Luke Skywalker'}, {'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Darth Vader'}, {'name': 'Leia Organa'}, {'name': 'Owen Lars'}, {'name': 'Beru Whitesun lars'}, {'name': 'R5-D4'}, {'name': 'Biggs Darklighter'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Wilhuff Tarkin'}, {'name': 'Chewbacca'}, {'name': 'Han Solo'}, {'name': 'Greedo'}, {'name': 'Jabba Desilijic Tiure'}, {'name': 'Wedge Antilles'}, {'name': 'Jek Tono Porkins'}, {'name': 'Raymus Antilles'}]}}}, {'node': {'title': 'The Empire Strikes Back', 'characterConnection': {'characters': [{'name': 'Luke Skywalker'}, {'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Darth Vader'}, {'name': 'Leia Organa'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Chewbacca'}, {'name': 'Han Solo'}, {'name': 'Wedge Antilles'}, {'name': 'Yoda'}, {'name': 'Palpatine'}, {'name': 'Boba Fett'}, {'name': 'IG-88'}, {'name': 'Bossk'}, {'name': 'Lando Calrissian'}, {'name': 'Lobot'}]}}}, {'node': {'title': 'Return of the Jedi', 'characterConnection': {'characters': [{'name': 'Luke Skywalker'}, {'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Darth Vader'}, {'name': 'Leia Organa'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Chewbacca'}, {'name': 'Han Solo'}, {'name': 'Jabba Desilijic Tiure'}, {'name': 'Wedge Antilles'}, {'name': 'Yoda'}, {'name': 'Palpatine'}, {'name': 'Boba Fett'}, {'name': 'Lando Calrissian'}, {'name': 'Ackbar'}, {'name': 'Mon Mothma'}, {'name': 'Arvel Crynyd'}, {'name': 'Wicket Systri Warrick'}, {'name': 'Nien Nunb'}, {'name': 'Bib Fortuna'}]}}}, {'node': {'title': 'The Phantom Menace', 'characterConnection': {'characters': [{'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Anakin Skywalker'}, {'name': 'Jabba Desilijic Tiure'}, {'name': 'Yoda'}, {'name': 'Palpatine'}, {'name': 'Qui-Gon Jinn'}, {'name': 'Nute Gunray'}, {'name': 'Finis Valorum'}, {'name': 'Padmé Amidala'}, {'name': 'Jar Jar Binks'}, {'name': 'Roos Tarpals'}, {'name': 'Rugor Nass'}, {'name': 'Ric Olié'}, {'name': 'Watto'}, {'name': 'Sebulba'}, {'name': 'Quarsh Panaka'}, {'name': 'Shmi Skywalker'}, {'name': 'Darth Maul'}, {'name': 'Ayla Secura'}, {'name': 'Ratts Tyerel'}, {'name': 'Dud Bolt'}, {'name': 'Gasgano'}, {'name': 'Ben Quadinaros'}, {'name': 'Mace Windu'}, {'name': 'Ki-Adi-Mundi'}, {'name': 'Kit Fisto'}, {'name': 'Eeth Koth'}, {'name': 'Adi Gallia'}, {'name': 'Saesee Tiin'}, {'name': 'Yarael Poof'}, {'name': 'Plo Koon'}, {'name': 'Mas Amedda'}]}}}, {'node': {'title': 'Attack of the Clones', 'characterConnection': {'characters': [{'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Owen Lars'}, {'name': 'Beru Whitesun lars'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Anakin Skywalker'}, {'name': 'Yoda'}, {'name': 'Palpatine'}, {'name': 'Boba Fett'}, {'name': 'Nute Gunray'}, {'name': 'Padmé Amidala'}, {'name': 'Jar Jar Binks'}, {'name': 'Watto'}, {'name': 'Shmi Skywalker'}, {'name': 'Ayla Secura'}, {'name': 'Mace Windu'}, {'name': 'Ki-Adi-Mundi'}, {'name': 'Kit Fisto'}, {'name': 'Plo Koon'}, {'name': 'Mas Amedda'}, {'name': 'Gregar Typho'}, {'name': 'Cordé'}, {'name': 'Cliegg Lars'}, {'name': 'Poggle the Lesser'}, {'name': 'Luminara Unduli'}, {'name': 'Barriss Offee'}, {'name': 'Dormé'}, {'name': 'Dooku'}, {'name': 'Bail Prestor Organa'}, {'name': 'Jango Fett'}, {'name': 'Zam Wesell'}, {'name': 'Dexter Jettster'}, {'name': 'Lama Su'}, {'name': 'Taun We'}, {'name': 'Jocasta Nu'}, {'name': 'R4-P17'}, {'name': 'Wat Tambor'}, {'name': 'San Hill'}, {'name': 'Shaak Ti'}, {'name': 'Sly Moore'}]}}}, {'node': {'title': 'Revenge of the Sith', 'characterConnection': {'characters': [{'name': 'Luke Skywalker'}, {'name': 'C-3PO'}, {'name': 'R2-D2'}, {'name': 'Darth Vader'}, {'name': 'Leia Organa'}, {'name': 'Owen Lars'}, {'name': 'Beru Whitesun lars'}, {'name': 'Obi-Wan Kenobi'}, {'name': 'Anakin Skywalker'}, {'name': 'Wilhuff Tarkin'}, {'name': 'Chewbacca'}, {'name': 'Yoda'}, {'name': 'Palpatine'}, {'nam ...

# %% [markdown]
# ---------------------------
